# %% [markdown]
# ## Universidad Autonoma de Aguascalientes
# ## Carrera: Ingenieria en Computación Inteligente
# ## Curso: Aprendizaje Inteligente
# ## Maestro: Dr. Francisco Javier Luna Rosas
# ## Alumno: Martin Isai Nunez Villeda
# ## Semestre: Enero-Junio del 2026

# %% [markdown]
# # Practica 7: Redes Neuronales (SCIKIT-LEARN_MPLClassifier) para realizar análisis de sentimientos

# %% [markdown]
# ## Paso 1: Importar las librerias necesarias

# %%
import pandas as pd
import numpy as np
from gensim.models import Word2Vec
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# ## Paso 2: Cargamos el dataset y lo separamos en review y sentiment, ya que son es un único arreglo de información

# %%
df = pd.read_csv('movie_data.csv', sep='\t')
df[['review', 'sentiment']] = df['review,sentiment'].str.rsplit(',', n=1, expand=True)

print(df.head())
# Out:
#                                     review,sentiment  \
# 0  In 1974, the teenager Martha Moxley (Maggie Gr...
# 1  OK... so... I really like Kris Kristofferson a...
# 2  ***SPOILER*** Do not read this, if you think a...
# 3  hi for all the people who have seen this wonde...
# 4  I recently bought the DVD, forgetting just how...
#
#                                               review sentiment
# 0  In 1974, the teenager Martha Moxley (Maggie Gr...         1
# 1  OK... so... I really like Kris Kristofferson a...         0
# 2  ***SPOILER*** Do not read this, if you think a...         0
# 3  hi for all the people who have seen this wonde...         1
# 4  I recently bought the DVD, forgetting just how...         0

# %% [markdown]
# ## Paso 3: Convertimos la columna review en un arreglo (variable predectora)

# %%
array_df0 = df['review'].to_numpy()

print("array_df0:", array_df0[:5])   # primeras 5
# Out:
# array_df0: ['In 1974, the teenager Martha Moxley (Maggie Grace) moves to the high-class area of Belle Haven, Greenwich, Connecticut. On the Mischief Night, eve of Halloween, she was murdered in the backyard of her house and her murder remained unsolved. Twenty-two years later, the writer Mark Fuhrman (Christopher Meloni), who is a former LA detective that has fallen in disgrace for perjury in O.J. Simpson trial and moved to Idaho, decides to investigate the case with his partner Stephen Weeks (Andrew Mitchell) with the purpose of writing a book. The locals squirm and do not welcome them, but with the support of the retired detective Steve Carroll (Robert Forster) that was in charge of the investigation in the 70\'s, they discover the criminal and a net of power and money to cover the murder.<br /><br />"Murder in Greenwich" is a good TV movie, with the true story of a murder of a fifteen years old girl that was committed by a wealthy teenager whose mother was a Kennedy. The powerful and rich family used their influence to cover the murder for more than twenty years. However, a snoopy detective and convicted perjurer in disgrace was able to disclose how the hideous crime was committed. The screenplay shows the investigation of Mark and the last days of Martha in parallel, but there is a lack of the emotion in the dramatization. My vote is seven.<br /><br />Title (Brazil): Not Available'
#  "OK... so... I really like Kris Kristofferson and his usual easy going delivery of lines in his movies. Age has helped him with his soft spoken low energy style and he will steal a scene effortlessly. But, Disappearance is his misstep. Holy Moly, this was a bad movie! <br /><br />I must give kudos to the cinematography and and the actors, including Kris, for trying their darndest to make sense from this goofy, confusing story! None of it made sense and Kris probably didn't understand it either and he was just going through the motions hoping someone would come up to him and tell him what it was all about! <br /><br />I don't care that everyone on this movie was doing out of love for the project, or some such nonsense... I've seen low budget movies that had a plot for goodness sake! This had none, zilcho, nada, zippo, empty of reason... a complete waste of good talent, scenery and celluloid! <br /><br />I rented this piece of garbage for a buck, and I want my money back! I want my 2 hours back I invested on this Grade F waste of my time! Don't watch this movie, or waste 1 minute of your valuable time while passing through a room where it's playing or even open up the case that is holding the DVD! Believe me, you'll thank me for the advice!"
#  '***SPOILER*** Do not read this, if you think about watching that movie, although it would be a waste of time. (By the way: The plot is so predictable that it does not make any difference if you read this or not anyway)<br /><br />If you are wondering whether to see "Coyote Ugly" or not: don\'t! It\'s not worth either the money for the ticket or the VHS / DVD. A typical "Chick-Feel-Good-Flick", one could say. The plot itself is as shallow as it can be, a ridiculous and uncritical version of the American Dream. The young good-looking girl from a small town becoming a big success in New York. The few desperate attempts of giving the movie any depth fail, such as the "tragic" accident of the father, the "difficulties" of Violet\'s relationship with her boyfriend, and so on. McNally (Director) tries to arouse the audience\'s pity and sadness put does not have any chance to succeed in this attempt due to the bad script and the shallow acting. Especially Piper Perabo completely fails in convincing one of "Jersey\'s" fear of singing in front of an audience. The only good (and quite funny thing) about "Coyote Ugly" is John Goodman, who represents the small ray of hope of this movie.<br /><br />I was very astonished, that Jerry Bruckheimer produced this movie. First "Gone In 60 Seconds" and now this... what happened to great movies like "The Rock" and "Con Air"? THAT was true Bruckheimer stuff.<br /><br />If you are looking for a superficial movie with good looking women just to have a relaxed evening, you should better go and see "Charlie\'s Angels" (it\'s much more funny, entertaining and self-ironic) instead of this flick.<br /><br />Two thumbs down (3 out of 10).'
#  'hi for all the people who have seen this wonderful movie im sure thet you would have liked it as much as i. i love the songs once you have seen the show you can sing along as though you are part of the show singing and dancing . dancing and singing. the song ONE is an all time fave musical song too and the strutters at the end with the mirror its so oh you have to watch this one'
#  'I recently bought the DVD, forgetting just how much I hated the movie version of "A Chorus Line." Every change the director Attenborough made to the story failed.<br /><br />By making the Director-Cassie relationship so prominent, the entire ensemble-premise of the musical sails out the window.<br /><br />Some of the musical numbers are sped up and rushed. The show\'s hit song gets the entire meaning shattered when it is given to Cassie\'s character.<br /><br />The overall staging is very self-conscious.<br /><br />The only reason I give it a 2, is because a few of the great numbers are still able to be enjoyed despite the film\'s attempt to squeeze every bit of joy and spontaneity out of it.']

# %% [markdown]
# ## Paso 4: Convertimos la columna sentiment en un arreglo (variable a predecir)

# %%
array_df1 = df['sentiment'].to_numpy()

print("array_df1:", array_df1[:5])   # primeras 5
# Out:
# array_df1: ['1' '0' '0' '1' '0']

# %% [markdown]
# ## Paso 5: Realizamos carpinteria de datos tokenizando el arreglo reviews

# %%
documents = [doc.split() for doc in array_df0]  

print("Ejemplo documento tokenizado:", documents[0][:20])
# Out:
# Ejemplo documento tokenizado: ['In', '1974,', 'the', 'teenager', 'Martha', 'Moxley', '(Maggie', 'Grace)', 'moves', 'to', 'the', 'high-class', 'area', 'of', 'Belle', 'Haven,', 'Greenwich,', 'Connecticut.', 'On', 'the']

# %% [markdown]
# ## Paso 6: Entrenamos con Word2Vec

# %%
w2v_model = Word2Vec(
    sentences=documents,
    vector_size=100,     # dimensión del embedding
    window=5,
    min_count=2,
    workers=4
)

print("Tamaño del vocabulario W2V:", len(w2v_model.wv))
# Out:
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Tamaño del vocabulario W2V: 169860

# %% [markdown]
# ## Paso 7: Generamos los vectores por reseña

# %%
def doc_vector(tokens, model):
    vecs = [model.wv[word] for word in tokens if word in model.wv]
    if len(vecs) == 0:
        return np.zeros(model.vector_size)
    return np.mean(vecs, axis=0)

X_w2v = np.array([doc_vector(tokens, w2v_model) for tokens in documents])

print("Shape X_w2v:", X_w2v.shape)   # (50000, 100)
# Out:
# Shape X_w2v: (50000, 100)

# %% [markdown]
# ## Paso 8: Se separan los datos con el 70% de los datos para entrenamiento y el 30% para testing

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_w2v, array_df1, train_size=0.7, random_state=0
)

# %% [markdown]
# ## Paso 9: Entrenamos nuestro modelo con una red neuronal NNBP.

# %%
clf = MLPClassifier(
    hidden_layer_sizes=(100,), #le metemos 100 capas ocultas
    activation='relu',
    solver='adam',
    max_iter=1000, #le metemos 1000 iteraciones como maximo para la convergencia del resultado, en caso contrario necesitara mas para mejorar
    verbose=True
)

clf.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 0.53785050
# Iteration 2, loss = 0.42513597
# Iteration 3, loss = 0.40941139
# Iteration 4, loss = 0.40556910
# Iteration 5, loss = 0.40082143
# Iteration 6, loss = 0.40064752
# Iteration 7, loss = 0.39686716
# Iteration 8, loss = 0.39381751
# Iteration 9, loss = 0.39255356
# Iteration 10, loss = 0.39111039
# Iteration 11, loss = 0.38849794
# Iteration 12, loss = 0.38870985
# Iteration 13, loss = 0.38626970
# Iteration 14, loss = 0.38524051
# Iteration 15, loss = 0.38297339
# Iteration 16, loss = 0.38151113
# Iteration 17, loss = 0.38118693
# Iteration 18, loss = 0.37963967
# Iteration 19, loss = 0.37873512
# Iteration 20, loss = 0.37794953
# Iteration 21, loss = 0.37696505
# Iteration 22, loss = 0.37501456
# Iteration 23, loss = 0.37369126
# Iteration 24, loss = 0.37233911
# Iteration 25, loss = 0.37343394
# Iteration 26, loss = 0.37029414
# Iteration 27, loss = 0.37140508
# Iteration 28, loss = 0.37128338
# Iteration 29, loss = 0.36811127
# Iteration 30, loss = 0.36733286
# Iteration 31, loss = 0.36574213
# Iteration 32, loss = 0.36553759
# Iteration 33, loss = 0.36415630
# Iteration 34, loss = 0.36426230
# Iteration 35, loss = 0.36607293
# Iteration 36, loss = 0.36191922
# Iteration 37, loss = 0.36106169
# Iteration 38, loss = 0.36114071
# Iteration 39, loss = 0.35997409
# Iteration 40, loss = 0.35920527
# Iteration 41, loss = 0.36025095
# Iteration 42, loss = 0.35733618
# Iteration 43, loss = 0.35604326
# Iteration 44, loss = 0.35584050
# Iteration 45, loss = 0.35612709
# Iteration 46, loss = 0.35523191
# Iteration 47, loss = 0.35392299
# Iteration 48, loss = 0.35318926
# Iteration 49, loss = 0.35173702
# Iteration 50, loss = 0.35215750
# Iteration 51, loss = 0.35139993
# Iteration 52, loss = 0.35028006
# Iteration 53, loss = 0.34903838
# Iteration 54, loss = 0.34970731
# Iteration 55, loss = 0.34861603
# Iteration 56, loss = 0.35017367
# Iteration 57, loss = 0.34737751
# Iteration 58, loss = 0.34622511
# Iteration 59, loss = 0.34660699
# Iteration 60, loss = 0.34786237
# Iteration 61, loss = 0.34578380
# Iteration 62, loss = 0.34352350
# Iteration 63, loss = 0.34218196
# Iteration 64, loss = 0.34225919
# Iteration 65, loss = 0.34137753
# Iteration 66, loss = 0.34189864
# Iteration 67, loss = 0.34277993
# Iteration 68, loss = 0.33932275
# Iteration 69, loss = 0.34177571
# Iteration 70, loss = 0.33999225
# Iteration 71, loss = 0.33946848
# Iteration 72, loss = 0.34039556
# Iteration 73, loss = 0.33739367
# Iteration 74, loss = 0.33690203
# Iteration 75, loss = 0.33734042
# Iteration 76, loss = 0.33830289
# Iteration 77, loss = 0.33536114
# Iteration 78, loss = 0.33467825
# Iteration 79, loss = 0.33539480
# Iteration 80, loss = 0.33507508
# Iteration 81, loss = 0.33364994
# Iteration 82, loss = 0.33259640
# Iteration 83, loss = 0.33250974
# Iteration 84, loss = 0.33243190
# Iteration 85, loss = 0.33149887
# Iteration 86, loss = 0.33187027
# Iteration 87, loss = 0.33082115
# Iteration 88, loss = 0.32883574
# Iteration 89, loss = 0.32843601
# Iteration 90, loss = 0.32932924
# Iteration 91, loss = 0.32943372
# Iteration 92, loss = 0.32899494
# Iteration 93, loss = 0.32764887
# Iteration 94, loss = 0.32896910
# Iteration 95, loss = 0.32572929
# Iteration 96, loss = 0.32536863
# Iteration 97, loss = 0.32609940
# Iteration 98, loss = 0.32541386
# Iteration 99, loss = 0.32665782
# Iteration 100, loss = 0.32644546
# Iteration 101, loss = 0.32473288
# Iteration 102, loss = 0.32346977
# Iteration 103, loss = 0.32154170
# Iteration 104, loss = 0.32427721
# Iteration 105, loss = 0.32590087
# Iteration 106, loss = 0.31981160
# Iteration 107, loss = 0.32151767
# Iteration 108, loss = 0.32233971
# Iteration 109, loss = 0.31920342
# Iteration 110, loss = 0.31940861
# Iteration 111, loss = 0.31960065
# Iteration 112, loss = 0.32054950
# Iteration 113, loss = 0.31940054
# Iteration 114, loss = 0.31965372
# Iteration 115, loss = 0.31566817
# Iteration 116, loss = 0.31713323
# Iteration 117, loss = 0.31821890
# Iteration 118, loss = 0.31605958
# Iteration 119, loss = 0.31930710
# Iteration 120, loss = 0.31735314
# Iteration 121, loss = 0.31466359
# Iteration 122, loss = 0.31530075
# Iteration 123, loss = 0.31600724
# Iteration 124, loss = 0.31280078
# Iteration 125, loss = 0.31246410
# Iteration 126, loss = 0.31285566
# Iteration 127, loss = 0.31288906
# Iteration 128, loss = 0.31225169
# Iteration 129, loss = 0.31053926
# Iteration 130, loss = 0.31222516
# Iteration 131, loss = 0.31145802
# Iteration 132, loss = 0.31216296
# Iteration 133, loss = 0.30929297
# Iteration 134, loss = 0.31406776
# Iteration 135, loss = 0.30892395
# Iteration 136, loss = 0.30929854
# Iteration 137, loss = 0.30733186
# Iteration 138, loss = 0.30754045
# Iteration 139, loss = 0.30767652
# Iteration 140, loss = 0.30758377
# Iteration 141, loss = 0.30643705
# Iteration 142, loss = 0.30676759
# Iteration 143, loss = 0.30651836
# Iteration 144, loss = 0.30466086
# Iteration 145, loss = 0.30615742
# Iteration 146, loss = 0.30714517
# Iteration 147, loss = 0.30355453
# Iteration 148, loss = 0.30405151
# Iteration 149, loss = 0.30484781
# Iteration 150, loss = 0.30161374
# Iteration 151, loss = 0.30445857
# Iteration 152, loss = 0.30270075
# Iteration 153, loss = 0.30267857
# Iteration 154, loss = 0.30167291
# Iteration 155, loss = 0.30118398
# Iteration 156, loss = 0.30055311
# Iteration 157, loss = 0.30167522
# Iteration 158, loss = 0.29891448
# Iteration 159, loss = 0.29909196
# Iteration 160, loss = 0.30063919
# Iteration 161, loss = 0.29888806
# Iteration 162, loss = 0.29772817
# Iteration 163, loss = 0.29934904
# Iteration 164, loss = 0.29961659
# Iteration 165, loss = 0.29671969
# Iteration 166, loss = 0.29866254
# Iteration 167, loss = 0.29857637
# Iteration 168, loss = 0.29759865
# Iteration 169, loss = 0.29531195
# Iteration 170, loss = 0.29441135
# Iteration 171, loss = 0.30026638
# Iteration 172, loss = 0.29470737
# Iteration 173, loss = 0.29403872
# Iteration 174, loss = 0.29575047
# Iteration 175, loss = 0.29219945
# Iteration 176, loss = 0.29354945
# Iteration 177, loss = 0.29321535
# Iteration 178, loss = 0.29222159
# Iteration 179, loss = 0.29493820
# Iteration 180, loss = 0.29124108
# Iteration 181, loss = 0.29380369
# Iteration 182, loss = 0.29142179
# Iteration 183, loss = 0.29234638
# Iteration 184, loss = 0.28932347
# Iteration 185, loss = 0.28930636
# Iteration 186, loss = 0.29132328
# Iteration 187, loss = 0.28959988
# Iteration 188, loss = 0.28978443
# Iteration 189, loss = 0.28950253
# Iteration 190, loss = 0.29288461
# Iteration 191, loss = 0.28850359
# Iteration 192, loss = 0.28781262
# Iteration 193, loss = 0.28655784
# Iteration 194, loss = 0.28755060
# Iteration 195, loss = 0.28632826
# Iteration 196, loss = 0.28554404
# Iteration 197, loss = 0.28645357
# Iteration 198, loss = 0.28427518
# Iteration 199, loss = 0.28519642
# Iteration 200, loss = 0.28694729
# Iteration 201, loss = 0.28189085
# Iteration 202, loss = 0.28517960
# Iteration 203, loss = 0.28502641
# Iteration 204, loss = 0.28597986
# Iteration 205, loss = 0.28434763
# Iteration 206, loss = 0.28174013
# Iteration 207, loss = 0.28439181
# Iteration 208, loss = 0.28372923
# Iteration 209, loss = 0.28128943
# Iteration 210, loss = 0.28346719
# Iteration 211, loss = 0.28511958
# Iteration 212, loss = 0.27925584
# Iteration 213, loss = 0.28206779
# Iteration 214, loss = 0.28167439
# Iteration 215, loss = 0.27889029
# Iteration 216, loss = 0.27715245
# Iteration 217, loss = 0.27824429
# Iteration 218, loss = 0.27743544
# Iteration 219, loss = 0.27969769
# Iteration 220, loss = 0.27802129
# Iteration 221, loss = 0.27824053
# Iteration 222, loss = 0.27819441
# Iteration 223, loss = 0.27582609
# Iteration 224, loss = 0.27556342
# Iteration 225, loss = 0.27597727
# Iteration 226, loss = 0.27586176
# Iteration 227, loss = 0.27566802
# Iteration 228, loss = 0.27777311
# Iteration 229, loss = 0.27490188
# Iteration 230, loss = 0.27575280
# Iteration 231, loss = 0.27673715
# Iteration 232, loss = 0.27787826
# Iteration 233, loss = 0.27537530
# Iteration 234, loss = 0.27240717
# Iteration 235, loss = 0.27001991
# Iteration 236, loss = 0.27126010
# Iteration 237, loss = 0.27088354
# Iteration 238, loss = 0.27120927
# Iteration 239, loss = 0.27202627
# Iteration 240, loss = 0.27001732
# Iteration 241, loss = 0.26965705
# Iteration 242, loss = 0.26998012
# Iteration 243, loss = 0.27349077
# Iteration 244, loss = 0.27282195
# Iteration 245, loss = 0.27169167
# Iteration 246, loss = 0.27324233
# Iteration 247, loss = 0.26973980
# Iteration 248, loss = 0.27336862
# Iteration 249, loss = 0.26895478
# Iteration 250, loss = 0.26769288
# Iteration 251, loss = 0.26863565
# Iteration 252, loss = 0.26894767
# Iteration 253, loss = 0.26589302
# Iteration 254, loss = 0.26810815
# Iteration 255, loss = 0.26711145
# Iteration 256, loss = 0.26945673
# Iteration 257, loss = 0.26739103
# Iteration 258, loss = 0.26705753
# Iteration 259, loss = 0.26954528
# Iteration 260, loss = 0.26441331
# Iteration 261, loss = 0.26531215
# Iteration 262, loss = 0.26590608
# Iteration 263, loss = 0.26556064
# Iteration 264, loss = 0.26530990
# Iteration 265, loss = 0.26400316
# Iteration 266, loss = 0.26384225
# Iteration 267, loss = 0.26500079
# Iteration 268, loss = 0.26779790
# Iteration 269, loss = 0.26390753
# Iteration 270, loss = 0.26204852
# Iteration 271, loss = 0.26414228
# Iteration 272, loss = 0.26099146
# Iteration 273, loss = 0.26505975
# Iteration 274, loss = 0.26132858
# Iteration 275, loss = 0.25922014
# Iteration 276, loss = 0.25924587
# Iteration 277, loss = 0.26307157
# Iteration 278, loss = 0.26206483
# Iteration 279, loss = 0.26058969
# Iteration 280, loss = 0.25874037
# Iteration 281, loss = 0.26040118
# Iteration 282, loss = 0.25828399
# Iteration 283, loss = 0.25662342
# Iteration 284, loss = 0.25783145
# Iteration 285, loss = 0.25728651
# Iteration 286, loss = 0.26035653
# Iteration 287, loss = 0.25533350
# Iteration 288, loss = 0.25835022
# Iteration 289, loss = 0.25902705
# Iteration 290, loss = 0.25837467
# Iteration 291, loss = 0.25705215
# Iteration 292, loss = 0.25628329
# Iteration 293, loss = 0.25635933
# Iteration 294, loss = 0.25562963
# Iteration 295, loss = 0.25630154
# Iteration 296, loss = 0.25285103
# Iteration 297, loss = 0.25444076
# Iteration 298, loss = 0.25623696
# Iteration 299, loss = 0.25382155
# Iteration 300, loss = 0.25236358
# Iteration 301, loss = 0.25589448
# Iteration 302, loss = 0.25376933
# Iteration 303, loss = 0.25556867
# Iteration 304, loss = 0.25150410
# Iteration 305, loss = 0.25374207
# Iteration 306, loss = 0.25843685
# Iteration 307, loss = 0.25557684
# Iteration 308, loss = 0.25496336
# Iteration 309, loss = 0.25026781
# Iteration 310, loss = 0.24928544
# Iteration 311, loss = 0.25323353
# Iteration 312, loss = 0.25129067
# Iteration 313, loss = 0.25068041
# Iteration 314, loss = 0.25475548
# Iteration 315, loss = 0.25032441
# Iteration 316, loss = 0.25322155
# Iteration 317, loss = 0.25286087
# Iteration 318, loss = 0.25437489
# Iteration 319, loss = 0.24804285
# Iteration 320, loss = 0.25072367
# Iteration 321, loss = 0.24859049
# Iteration 322, loss = 0.25099645
# Iteration 323, loss = 0.24875477
# Iteration 324, loss = 0.24677516
# Iteration 325, loss = 0.24552369
# Iteration 326, loss = 0.25151565
# Iteration 327, loss = 0.24767493
# Iteration 328, loss = 0.24959277
# Iteration 329, loss = 0.25038459
# Iteration 330, loss = 0.24811503
# Iteration 331, loss = 0.24426568
# Iteration 332, loss = 0.24760721
# Iteration 333, loss = 0.24634135
# Iteration 334, loss = 0.24369893
# Iteration 335, loss = 0.24551011
# Iteration 336, loss = 0.24432212
# Iteration 337, loss = 0.24823985
# Iteration 338, loss = 0.24635517
# Iteration 339, loss = 0.24716649
# Iteration 340, loss = 0.24356293
# Iteration 341, loss = 0.24529391
# Iteration 342, loss = 0.24274130
# Iteration 343, loss = 0.24383567
# Iteration 344, loss = 0.24389913
# Iteration 345, loss = 0.24701427
# Iteration 346, loss = 0.24714014
# Iteration 347, loss = 0.24273029
# Iteration 348, loss = 0.24526566
# Iteration 349, loss = 0.24378534
# Iteration 350, loss = 0.24140285
# Iteration 351, loss = 0.23905640
# Iteration 352, loss = 0.24260137
# Iteration 353, loss = 0.24509235
# Iteration 354, loss = 0.24173691
# Iteration 355, loss = 0.25074053
# Iteration 356, loss = 0.24113435
# Iteration 357, loss = 0.24415707
# Iteration 358, loss = 0.23942749
# Iteration 359, loss = 0.23989355
# Iteration 360, loss = 0.24408964
# Iteration 361, loss = 0.24257573
# Iteration 362, loss = 0.23995056
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(max_iter=1000, verbose=True)

# %% [markdown]
# ## Paso 10: Imprimimos nuestros resultados.

# %%
y_pred = clf.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8043333333333333
#               precision    recall  f1-score   support
#
#            0       0.77      0.85      0.81      7342
#            1       0.84      0.76      0.80      7658
#
#     accuracy                           0.80     15000
#    macro avg       0.81      0.81      0.80     15000
# weighted avg       0.81      0.80      0.80     15000

# %% [markdown]
# ## Referencias
# ### Russell S.J., Norvig P. (2020). Artifical Intelligence: A Modern Approach, Prentine-Hall, 4th Edition, Englewood Cliffs, NJ, 2020.
# ### Kevin (2025). NEURONA DEl Modelo de McCulloch Pitts. https://www.youtube.com/watch?v=ROErFR3X4x0 (Ultimo acceso Febrero 2025)
# ### OpenAI. (2025). ChatGPT (modelo GPT-5.2)[Modelo de lenguaje grande].https://chatgpt.com/
